# %% [markdown]
# ### Indexing dataset where indexing was forgotten

# %%
import gc
from tqdm.auto import tqdm
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrow.dataset as ds
import pandas as pd
import os
# Set Arrow CPU count as in your helper
pa.set_cpu_count(8)

job_id='dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-ouutovygqc'
input_dir = f"../../extractions/{job_id}/input_articles_tiled"
output_dir = f"../../extractions/{job_id}/input_articles_tiled_indexed"
os.makedirs(output_dir, exist_ok=True)

dataset = ds.dataset(input_dir, format="parquet")
total_rows = 0
for batch in dataset.scanner().to_batches():
    total_rows += len(batch)
print(f"Total rows: {total_rows}")
# Out:
# Total rows: 3058995

# %%
# newer code - test next time
year_dirs = sorted([d for d in os.listdir(input_dir) if d.startswith('year=')])
current_index = 0

for year_dir in tqdm(year_dirs, desc="Processing years"):
    year_path = os.path.join(input_dir, year_dir)
    output_year_path = os.path.join(output_dir, year_dir)
    os.makedirs(output_year_path, exist_ok=True)
    
    month_dirs = sorted([d for d in os.listdir(year_path) if d.startswith('month=')])
    
    for month_dir in tqdm(month_dirs, desc=f"Processing months in {year_dir}", leave=False):
        month_path = os.path.join(year_path, month_dir)
        output_month_path = os.path.join(output_year_path, month_dir)
        os.makedirs(output_month_path, exist_ok=True)
        
        # Get all parquet files for this month
        parquet_files = sorted([f for f in os.listdir(month_path) if f.endswith('.parquet')])
        
        for file in tqdm(parquet_files, desc=f"Files in {month_dir}", leave=False):
            file_path = os.path.join(month_path, file)
            output_file_path = os.path.join(output_month_path, file)
            
            # Read file with pandas
            df = pd.read_parquet(file_path)
            
            # Add tile_id column
            df['tile_id'] = range(current_index, current_index + len(df))
            current_index += len(df)
            
            # Write the file directly to the output location with same name
            df.to_parquet(output_file_path, compression="zstd", index=False)
            
            # Clean up
            del df
            gc.collect()

print(f"Processed {current_index} rows, final index: {current_index}")
print(f"Output saved to: {output_dir}")

# %%
## older code - works
year_dirs = sorted([d for d in os.listdir(input_dir) if d.startswith('year=')])

current_index = 0

for year_dir in tqdm(year_dirs, desc="Processing years"):
    year_path = os.path.join(input_dir, year_dir)
    # Extract the year value from the directory name
    year_value = int(year_dir.split('=')[1])
    
    month_dirs = sorted([d for d in os.listdir(year_path) if d.startswith('month=')])
    
    for month_dir in tqdm(month_dirs, desc=f"Processing months in {year_dir}", leave=False):
        month_path = os.path.join(year_path, month_dir)
        # Extract the month value from the directory name
        month_value = int(month_dir.split('=')[1])
        
        # Get all parquet files for this month
        parquet_files = sorted([f for f in os.listdir(month_path) if f.endswith('.parquet')])
        
        for file in tqdm(parquet_files, desc=f"Files in {month_dir}", leave=False):
            file_path = os.path.join(month_path, file)
            
            # Read file with pandas
            df = pd.read_parquet(file_path)
            
            # Add year and month columns explicitly based on directory names
            df['year'] = year_value
            df['month'] = month_value
            
            # Add tile_id column
            df['tile_id'] = range(current_index, current_index + len(df))
            current_index += len(df)
            
            # Process in batches of 250,000 rows exactly as in your helper
            batch_size = 250_000
            for start in range(0, len(df), batch_size):
                batch_df = df.iloc[start:start + batch_size]
                
                # Convert to table
                tbl = pa.Table.from_pandas(batch_df, preserve_index=False)
                
                # Write using the same parameters as your helper
                pq.write_to_dataset(
                    tbl,
                    root_path=output_dir,
                    partition_cols=["year", "month"],
                    compression="zstd",
                    existing_data_behavior="overwrite_or_ignore"
                )
                
                # Clean up
                del tbl
                gc.collect()
            
            # Clean up the full dataframe
            del df
            gc.collect()



print(f"Processed {current_index} rows, final index: {current_index}")
print(f"Output saved to: {output_dir}")

# %% [markdown]
# #### Checking indexing result

# %%
import datetime as dt
import pandas as pd

filter_date = dt.datetime(2025,1,1)
tiled_df = pd.read_parquet(f"../../extractions/{job_id}/input_articles_tiled_indexed",  filters=[("year","=",filter_date.year)],columns=["tile_id","segments","pub_date"])
tiled_df
# Out:
#          tile_id                                           segments   pub_date
# 0        1910601  Ownership Submission\n\nFORM 4\n\nCheck this b... 2025-01-17
# 1        1910602  \n\nWashington, D.C. 20549STATEMENT OF CHANGES... 2025-01-17
# 2        1910603  \n\nDigitalBridge Group, Inc. [DBRG] 5. Relati... 2025-01-17
# 3        1910604  \n\n(Instr. 3) 2. Transaction Date (Month/Day/... 2025-01-17
# 4        1910605  \n\n(Instr. 8) 5. Number of Derivative Securit... 2025-01-17
# ...          ...                                                ...        ...
# 1274951  2940041  FORM 4\n\nCheck this box if no longer subject ... 2025-05-05
# 1274952  2940042  \n\nWashington, D.C. 20549 STATEMENT OF CHANGE... 2025-05-05
# 1274953  2940043  \n\nCONSUMERS BANCORP INC /OH/ [CBKM] 5. Relat... 2025-05-05
# 1274954  2940044  \n\n(Month/Day/Year) 7. Title and Amount of Un... 2025-05-05
# 1274955  2940045   \n\n\nSignatures\n\n/s/Frank L. Paden        ... 2025-05-05
#
# [1274956 rows x 3 columns]

# %%
assert tiled_df.tile_id.min() == 1784039# same as if add tile_id on the whole file online

# %% [markdown]
# ### Merging with ssim dedup result

# %%
import pandas as pd

job_id='dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-ouutovygqc'
# df[df.tile_id>1784039] # tile_id for 2025-01-01
df = pd.read_parquet(f"../../extractions/{job_id}/input_articles_ssim.parquet")
df =df[df.tile_id>1784039][['segments','tile_id']] # tile_id for 2025-01-01
df
# Out:
#                                                  segments  tile_id
# 478381  compared with 4Q23 Net Earnings of $116 millio...  1784043
# 478382   \n                             \n\nCapital   ...  1784044
# 478383  \n\nMr. Simmons continued, "Net loan losses we...  1784045
# 478384  \n\nMr. Simmons concluded, "We're optimistic t...  1784046
# 478385   \n\n\n1 Comparisons noted in the bullet point...  1784047
# ...                                                   ...      ...
# 821903  Interest will be paid semi-annually and the Of...  3058966
# 821904  \n\nThis press release may include projections...  3058971
# 821905  Credit Agricole S.A.\n\n02 May 2025\n\nFORM 8....  3058972
# 821906  \n\n"It's the biggest single, buy-side deal in...  3058985
# 821907  \n\nDespite the emergence of an array of froze...  3058987
#
# [343527 rows x 2 columns]

# %%
# cols we need for further processing
import datetime as dt
filter_date = dt.datetime(2025,1,1)

cols2use = ['source_name','title','company_codes','modification_date','region_codes','segments','num_segments','an', 'tile_id'] #post-processing and filtering will be later
tiled_df = pd.read_parquet(f"../../extractions/{job_id}/input_articles_tiled_indexed", columns=cols2use, filters=[("year","=",filter_date.year)])
tiled_df.shape
# Out:
# (1274956, 9)

# %% [markdown]
# ## Filtering for region codes and preparing for run

# %%
region_codes = ['AUST', 'BELG', 'CZREP','DEN', 'ESTNIA','FIN', 'FRA','GFR', 'ITALY', 'LATV', 'IRE', 'ICEL', 'LITH', 'LUX', 'MALTA', 'NETH', 'NORW', 'POL', 'LARIO', 'SWED', 'SWITZ', 'UK', 'VIEN', 'BRUS', 'PRAGUE',
'COPEN', 'TALLIN','HELSNK', 'PARIS','BERLIN', 'ROME','RIGA', 'DUBLIN','REYK', 'VILNIU', 'LUXCI', 'VALLE', 'AMSTR', 'OSLO', 'WASW', 'MADRD', 'STOCK', 'BERN','DERRY']
region_codes += ["EURZ", "EEURZ", "WEURZ"]
region_codes = [el.lower() for el in region_codes]
region_codes[:5]
# Out:
# ['aust', 'belg', 'czrep', 'den', 'estnia']

# %%
from tqdm.auto import tqdm
tqdm.pandas()

def should_keep(region_codes_list):
    # Check if any of the region codes in the list are in the exclude list
    return any(code in region_codes_list for code in region_codes)

tiled_df['region_codes'] = tiled_df['region_codes'].str.strip(',')
tiled_df['region_codes_list'] = tiled_df['region_codes'].progress_apply(lambda x: x.split(',') if isinstance(x, str) else [])
tiled_df['regions_relevant'] = tiled_df['region_codes_list'].progress_apply(lambda x: should_keep(x))
# Out:
#   0%|          | 0/1274956 [00:00<?, ?it/s]
#   0%|          | 0/1274956 [00:00<?, ?it/s]

# %%
df2classify = tiled_df[tiled_df.tile_id.isin(df.tile_id) & tiled_df.regions_relevant].copy()
df2classify = df2classify.loc[ :, ~df2classify.columns.isin(['region_codes_list','regions_relevant'])]

df2classify
# Out:
#             source_name                                              title  \
# 19       Gulf Oil & Gas  Cleanova expands its product offering with the...
# 20       Gulf Oil & Gas  Cleanova expands its product offering with the...
# 21       Gulf Oil & Gas  Cleanova expands its product offering with the...
# 22       Gulf Oil & Gas  Cleanova expands its product offering with the...
# 145        thesun.co.uk  HIGH STREET GIANT WHSmith ‘in secret talks to ...
# ...                 ...                                                ...
# 1274940  thetimes.co.uk  Who could buy Bet365? Bankers salivate, but a ...
# 1274941  thetimes.co.uk  Who could buy Bet365? Bankers salivate, but a ...
# 1274942  thetimes.co.uk  Who could buy Bet365? Bankers salivate, but a ...
# 1274943  thetimes.co.uk  Who could buy Bet365? Bankers salivate, but a ...
# 1274944  thetimes.co.uk  Who could buy Bet365? Bankers salivate, but a ...
#
#                                              company_codes  \
# 19                              alvmar,cmbndi,dbvpl,percoi
# 20                              alvmar,cmbndi,dbvpl,percoi
# 21                              alvmar,cmbndi,dbvpl,percoi
# 22                              alvmar,cmbndi,dbvpl,percoi
# 145                        bhchcm,brraic,bsbro,lsexch,smwh
# ...                                                    ...
# 1274940  btsfgl,cnyc,cvccap,drftkn,gamvc,grdmp,habsaa,p...
# 1274941  btsfgl,cnyc,cvccap,drftkn,gamvc,grdmp,habsaa,p...
# 1274942  btsfgl,cnyc,cvccap,drftkn,gamvc,grdmp,habsaa,p...
# 1274943  btsfgl,cnyc,cvccap,drftkn,gamvc,grdmp,habsaa,p...
# 1274944  btsfgl,cnyc,cvccap,drftkn,gamvc,grdmp,habsaa,p...
#
#               modification_date   region_codes  \
# 19      2025-01-10 07:13:57.825  eurz,uk,weurz
# 20      2025-01-10 07:13:57.825  eurz,uk,weurz
# 21      2025-01-10 07:13:57.825  eurz,uk,weurz
# 22      2025-01-10 07:13:57.825  eurz,uk,weurz
# 145     2025-01-26 07:33:12.758  eurz,uk,weurz
# ...                         ...            ...
# 1274940 2025-05-04 07:19:19.010  eurz,uk,weurz
# 1274941 2025-05-04 07:19:19.010  eurz,uk,weurz
# 1274942 2025-05-04 07:19:19.010  eurz,uk,weurz
# 1274943 2025-05-04 07:19:19.010  eurz,uk,weurz
# 1274944 2025-05-04 07:19:19.010  eurz,uk,weurz
#
#                                                   segments  num_segments  \
# 19       Enhances Cleanova’s presence in the UK and bro...             4
# 20       \n\nCleanova, a clean tech, market-leading glo...             4
# 21       \n\nCleanova’s CEO, Javaid Riaz, commented, “T...             4
# 22       \n\nJavaid Riaz explained what the transition ...             4
# 145      The retail group have been in negotiations wit...             7
# ...                                                    ...           ...
# 1274940  \n\nJP Morgan was completely unaware that Coat...             7
# 1274941  \n\nBet365 has historically had a sizeable rem...             7
# 1274942  \n\nBut a sale risks bringing Coates into conf...             7
# 1274943  \n\nAccordingly a sale may be her only option,...             7
# 1274944  \n\nListed suitors are similarly limited. FTSE...             7
#
#                                 an  tile_id
# 19       GUONGA0020250109el170007b  1910620
# 20       GUONGA0020250109el170007b  1910621
# 21       GUONGA0020250109el170007b  1910622
# 22       GUONGA0020250109el170007b  1910623
# 145      THESUK0020250125el1p001jl  1910746
# ...                            ...      ...
# 1274940  TIMEUK0020250503el53000jh  2940030
# 1274941  TIMEUK0020250503el53000jh  2940031
# 1274942  TIMEUK0020250503el53000jh  2940032
# 1274943  TIMEUK0020250503el53000jh  2940033
# 1274944  TIMEUK0020250503el53000jh  2940034
#
# [135285 rows x 9 columns]

# %%
import sys, os
sys.path.append('../../')
from dotenv import load_dotenv
from src.factiva_api.taxonomy import init_client, get_company_code_mapping
from src.mapping.company_mapper import extract_company_names

load_dotenv('../../.env')

user_key = os.getenv("FACTIVA_SNAPSHOTS_USER_KEY")

client = init_client(user_key)
companies_mapping = get_company_code_mapping(client)

df2classify['company_names'] = df2classify['company_codes'].progress_apply(lambda x: extract_company_names(x, companies_mapping))
# Out:
# Duplicate indices found in 'companies' taxonomy. Keeping first. Note: this behavior is expected
#   0%|          | 0/135285 [00:00<?, ?it/s]

# %%
df2classify.to_csv(f'../../extractions/{job_id}/relevant_articles_to_classify_2025.csv', index=False)

# %% [markdown]
# ### Looking for article links

# %%
import datetime as dt
import pandas as pd
job_id='dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-ouutovygqc'

filter_date = dt.datetime(2025,1,1)
tiled_df = pd.read_parquet(f"../../extractions/{job_id}/input_articles_tiled_indexed", columns=None, filters=[("year","=",filter_date.year), ("month","=",filter_date.month)])

tiled_df
# Out:
#                                              source_name  \
# 0       Securities and Exchange Commission (SEC) Filings
# 1       Securities and Exchange Commission (SEC) Filings
# 2       Securities and Exchange Commission (SEC) Filings
# 3       Securities and Exchange Commission (SEC) Filings
# 4       Securities and Exchange Commission (SEC) Filings
# ...                                                  ...
# 243873  Securities and Exchange Commission (SEC) Filings
# 243874  Securities and Exchange Commission (SEC) Filings
# 243875  Securities and Exchange Commission (SEC) Filings
# 243876  Securities and Exchange Commission (SEC) Filings
# 243877  Securities and Exchange Commission (SEC) Filings
#
#                                                     title  \
# 0       Digitalbridge Group Inc. - Statement of Change...
# 1       Digitalbridge Group Inc. - Statement of Change...
# 2       Digitalbridge Group Inc. - Statement of Change...
# 3       Digitalbridge Group Inc. - Statement of Change...
# 4       Digitalbridge Group Inc. - Statement of Change...
# ...                                                   ...
# 243873  JPMorgan Chase & Co. - Primary Offering Prospe...
# 243874  JPMorgan Chase & Co. - Primary Offering Prospe...
# 243875  JPMorgan Chase & Co. - Primary Offering Prospe...
# 243876  JPMorgan Chase & Co. - Primary Offering Prospe...
# 243877  JPMorgan Chase & Co. - Primary Offering Prospe...
#
#                                                   snippet  \
# 0       Access the original document here\n\nStatement...
# 1       Access the original document here\n\nStatement...
# 2       Access the original document here\n\nStatement...
# 3       Access the original document here\n\nStatement...
# 4       Access the original document here\n\nStatement...
# ...                                                   ...
# 243873  Access the original document here\n\nPrimary O...
# 243874  Access the original document here\n\nPrimary O...
# 243875  Access the original document here\n\nPrimary O...
# 243876  Access the original document here\n\nPrimary O...
# 243877  Access the original document here\n\nPrimary O...
#
#                                                      body section  word_count  \
# 0       Ownership Submission\n\nFORM 4\n\nCheck this b...    None         857
# 1       Ownership Submission\n\nFORM 4\n\nCheck this b...    None         857
# 2       Ownership Submission\n\nFORM 4\n\nCheck this b...    None         857
# 3       Ownership Submission\n\nFORM 4\n\nCheck this b...    None         857
# 4       Ownership Submission\n\nFORM 4\n\nCheck this b...    None         857
# ...                                                   ...     ...         ...
# 243873  January 8, 2025\n\nRegistration Statement Nos....    None        8513
# 243874  January 8, 2025\n\nRegistration Statement Nos....    None        8513
# 243875  January 8, 2025\n\nRegistration Statement Nos....    None        8513
# 243876  January 8, 2025\n\nRegistration Statement Nos....    None        8513
# 243877  January 8, 2025\n\nRegistration Statement Nos....    None        8513
#
#        source_code                   industry_codes  \
# 0            SAEXC               ,i831,ifinal,iinv,
# 1            SAEXC               ,i831,ifinal,iinv,
# 2            SAEXC               ,i831,ifinal,iinv,
# 3            SAEXC               ,i831,ifinal,iinv,
# 4            SAEXC               ,i831,ifinal,iinv,
# ...            ...                              ...
# 243873       SAEXC  ,i814,i81402,ibnk,ifinal,iibnk,
# 243874       SAEXC  ,i814,i81402,ibnk,ifinal,iibnk,
# 243875       SAEXC  ,i814,i81402,ibnk,ifinal,iibnk,
# 243876       SAEXC  ,i814,i81402,ibnk,ifinal,iibnk,
# 243877       SAEXC  ,i814,i81402,ibnk,ifinal,iibnk,
#
#                                             company_codes  \
# 0                                                  nsassz
# 1                                                  nsassz
# 2                                                  nsassz
# 3                                                  nsassz
# 4                                                  nsassz
# ...                                                   ...
# 243873  blfima,cnyc,davpw,deptct,deptr,fdic,irevs,jpms...
# 243874  blfima,cnyc,davpw,deptct,deptr,fdic,irevs,jpms...
# 243875  blfima,cnyc,davpw,deptct,deptr,fdic,irevs,jpms...
# 243876  blfima,cnyc,davpw,deptct,deptr,fdic,irevs,jpms...
# 243877  blfima,cnyc,davpw,deptct,deptr,fdic,irevs,jpms...
#
#                                             subject_codes  ...  \
# 0       ,c18,c181,c41,cactio,ccat,cdirdl,cgvfil,cintrf...  ...
# 1       ,c18,c181,c41,cactio,ccat,cdirdl,cgvfil,cintrf...  ...
# 2       ,c18,c181,c41,cactio,ccat,cdirdl,cgvfil,cintrf...  ...
# 3       ,c18,c181,c41,cactio,ccat,cdirdl,cgvfil,cintrf...  ...
# 4       ,c18,c181,c41,cactio,ccat,cdirdl,cgvfil,cintrf...  ...
# ...                                                   ...  ...
# 243873  ,c15,c151,c1512,cactio,ccat,cgvfil,ncat,nfact,...  ...
# 243874  ,c15,c151,c1512,cactio,ccat,cgvfil,ncat,nfact,...  ...
# 243875  ,c15,c151,c1512,cactio,ccat,cgvfil,ncat,nfact,...  ...
# 243876  ,c15,c151,c1512,cactio,ccat,cgvfil,ncat,nfact,...  ...
# 243877  ,c15,c151,c1512,cactio,ccat,cgvfil,ncat,nfact,...  ...
#
#              modification_date region_codes                         an action  \
# 0      2025-01-18 07:24:27.686   ,namz,usa,  SAEXC00020250117el1h00o06    add
# 1      2025-01-18 07:24:27.686   ,namz,usa,  SAEXC00020250117el1h00o06    add
# 2      2025-01-18 07:24:27.686   ,namz,usa,  SAEXC00020250117el1h00o06    add
# 3      2025-01-18 07:24:27.686   ,namz,usa,  SAEXC00020250117el1h00o06    add
# 4      2025-01-18 07:24:27.686   ,namz,usa,  SAEXC00020250117el1h00o06    add
# ...                        ...          ...                        ...    ...
# 243873 2025-01-11 07:29:43.324   ,namz,usa,  SAEXC00020250110el1a00dff    add
# 243874 2025-01-11 07:29:43.324   ,namz,usa,  SAEXC00020250110el1a00dff    add
# 243875 2025-01-11 07:29:43.324   ,namz,usa,  SAEXC00020250110el1a00dff    add
# 243876 2025-01-11 07:29:43.324   ,namz,usa,  SAEXC00020250110el1a00dff    add
# 243877 2025-01-11 07:29:43.324   ,namz,usa,  SAEXC00020250110el1a00dff    add
#
#          pub_date                                           segments  \
# 0      2025-01-17  Ownership Submission\n\nFORM 4\n\nCheck this b...
# 1      2025-01-17  \n\nWashington, D.C. 20549STATEMENT OF CHANGES...
# 2      2025-01-17  \n\nDigitalBridge Group, Inc. [DBRG] 5. Relati...
# 3      2025-01-17  \n\n(Instr. 3) 2. Transaction Date (Month/Day/...
# 4      2025-01-17  \n\n(Instr. 8) 5. Number of Derivative Securit...
# ...           ...                                                ...
# 243873 2025-01-10  \n\nNotes" in this pricing supplement.\n\nSeco...
# 243874 2025-01-10  \n\nincluded in the original issue price of th...
# 243875 2025-01-10  \n\nReflected on Customer Account Statements) ...
# 243876 2025-01-10  \n\nnotes. See "How the Notes Work" and "Hypot...
# 243877 2025-01-10  \n\ncontemplated herein, such notes will be va...
#
#        num_segments  tile_id  year  month
# 0                 6  1910601  2025      1
# 1                 6  1910602  2025      1
# 2                 6  1910603  2025      1
# 3                 6  1910604  2025      1
# 4                 6  1910605  2025      1
# ...             ...      ...   ...    ...
# 243873           62  1991388  2025      1
# 243874           62  1991389  2025      1
# 243875           62  1991390  2025      1
# 243876           62  1991391  2025      1
# 243877           62  1991392  2025      1
#
# [243878 rows x 22 columns]

# %%
df = pd.read_csv(f"../../extractions/{job_id}/result.csv")
df
# Out:
#                                              source_name dateline  \
# 0                           Dow Jones Institutional News      NaN
# 1       Securities and Exchange Commission (SEC) Filings      NaN
# 2                                            PR Newswire      NaN
# 3           Public Companies News and Documents via PUBT      NaN
# 4                                      Canada Stockwatch      NaN
# ...                                                  ...      ...
# 223516  Securities and Exchange Commission (SEC) Filings      NaN
# 223517      Public Companies News and Documents via PUBT      NaN
# 223518                               Global Banking News      NaN
# 223519  Securities and Exchange Commission (SEC) Filings      NaN
# 223520                      Dow Jones Institutional News      NaN
#
#         ingestion_datetime currency_codes  \
# 0            1739355044000            NaN
# 1            1743191927000            NaN
# 2            1744722047000            NaN
# 3            1731288771000            NaN
# 4            1736895739000            NaN
# ...                    ...            ...
# 223516       1741210800000            NaN
# 223517       1742297491000            NaN
# 223518       1727705061000            NaN
# 223519       1715978722000            NaN
# 223520       1740060073000            NaN
#
#         company_codes_association_ticker_exchange  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 223516                                        NaN
# 223517                                        NaN
# 223518                                        NaN
# 223519                                        NaN
# 223520                                        NaN
#
#                                                     title  \
# 0       Press Release: XPENG announces its official la...
# 1       First Busey Corporation - Statement of Changes...
# 2       PLAUD.AI Acquires YC-Backed StarJar to Power I...
# 3       Shionogi & Co. Ltd. - SHIONOGI Story 2 :Busine...
# 4       Torex Gold Provides 2025 Operational Guidance ...
# ...                                                   ...
# 223516  Coinbase Global Inc. - Statement of Changes in...
# 223517  Almawave S.p.A. - Almawave and Oracle: strateg...
# 223518       QNB’s share buyback gets regulatory approval
# 223519  FNCB Bancorp Inc. - Amendment to Statement of ...
# 223520  Form 8.3 - The Vanguard Group, Inc.: Spirent C...
#
#                                                   snippet  \
# 0       \n   -- XPENG officially enters the UK, streng...
# 1       Access the original document here\n\nStatement...
# 2       SAN FRANCISCO, April 15, 2025 /PRNewswire/ -- ...
# 3       Access the original document here\n\nSHIONOGI ...
# 4       (All amounts expressed in U.S. dollars unless ...
# ...                                                   ...
# 223516  Access the original document here\n\nStatement...
# 223517  Access the original document here\n\nAlmawave ...
# 223518  Qatar-based banking firm QNB Group has said th...
# 223519  Access the original document here\n\nAmendment...
# 223520                                                NaN
#
#        company_codes_lineage_ticker_exchange                         an  \
# 0                                        NaN  DJDN000020250212el2c001sa
# 1                                        NaN  SAEXC00020250328el3s00cin
# 2                                        NaN  PRN0000020250415el4f000cs
# 3                                        NaN  LCDVP00020241111ekbb0020f
# 4                                        NaN  CNSW000020250114el1e00ifx
# ...                                      ...                        ...
# 223516                                   NaN  SAEXC00020250305el3500s1l
# 223517                                   NaN  LCDVP00020250318el3i00kwv
# 223518                                   NaN  GLOBAN0020240930ek9u000b9
# 223519                                   NaN  SAEXC00020240517ek5h00mt5
# 223520                                   NaN  DJDN000020250220el2k002ox
#
#                       company_codes_occur_ticker_exchange  ...  document_type  \
# 0                                                     NaN  ...        article
# 1                                                     NaN  ...        article
# 2       ,INTU:XWBO,1INTU:XMIL,INTU:XNAS,INTU:XMEX,ITU:...  ...        article
# 3       ,SGIOY:PSGM,SGIOF:PSGM,SH0:XFRA,SH00:XMUN,4507...  ...        article
# 4                                                     NaN  ...        article
# ...                                                   ...  ...            ...
# 223516                                                NaN  ...        article
# 223517                                                NaN  ...        article
# 223518                                                NaN  ...        article
# 223519                                                NaN  ...        article
# 223520                    ,EQS0:XETR,EQSTF:PSGM,EQS:XETR,  ...        article
#
#        modification_datetime  \
# 0              1739355044000
# 1              1743191927000
# 2              1744722047000
# 3              1731288771000
# 4              1736895739000
# ...                      ...
# 223516         1741210800000
# 223517         1742297491000
# 223518         1727705061000
# 223519         1715978722000
# 223520         1740060073000
#
#                                             company_codes action  \
# 0       ,bp,hkexch,hkexch,hsflia,hsflia,imotol,imotol,...    add
# 1                      ,firbus,firbus,firbus,seexc,seexc,    add
# 2       ,amzcom,amzcom,gognew,gognew,ituit,ituit,linkd...    add
# 3       ,pingin,pingin,shimc,shimc,shnogi,shnogi,shnog...    add
# 4                                  ,hydgld,hydgld,hydgld,    add
# ...                                                   ...    ...
# 223516                 ,coinba,coinba,coinba,seexc,seexc,    add
# 223517  ,hggngf,hggngf,kosco,kosco,orcle,orcle,orcle,p...    add
# 223518  ,qatfma,qatfma,qatfma,qbnk,qbnk,qbnk,qma,qma,q...    add
# 223519                             ,fstdun,fstdun,fstdun,    add
# 223520      ,bwth,bwth,bwth,eqstry,eqstry,vngd,vngd,vngd,    add
#
#                                              region_codes  \
# 0                                         ,eurz,uk,weurz,
# 1                                              ,namz,usa,
# 2                                ,namz,sfra,usa,usca,usw,
# 3       ,apacz,asiaz,china,chinaz,devgcoz,dvpcoz,easia...
# 4                                  ,cana,caon,namz,toron,
# ...                                                   ...
# 223516                                         ,namz,usa,
# 223517          ,eecz,eurz,italy,lombar,medz,milan,weurz,
# 223518                                                NaN
# 223519                                         ,namz,usa,
# 223520                                                NaN
#
#                   market_index_codes  \
# 0       ,xdjgic,xdjglc,xdjiic,xnyci,
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 223516                           NaN
# 223517                       ,xf500,
# 223518                           NaN
# 223519                           NaN
# 223520                           NaN
#
#                       company_codes_about_ticker_exchange  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       ,SGIOY:PSGM,SGIOF:PSGM,SH0:XFRA,SH00:XMUN,4507...
# 4                                                     NaN
# ...                                                   ...
# 223516                                                NaN
# 223517                                                NaN
# 223518                                                NaN
# 223519                                                NaN
# 223520                                                NaN
#
#                                      company_codes_occur  section  \
# 0                          ,myjjcc,imotol,hsflia,hkexch,      NaN
# 1                                         ,seexc,firbus,      NaN
# 2       ,yoinco,teslmi,pkxwks,linkd,ituit,gognew,amzcom,      NaN
# 3                           ,soneti,shnogi,shimc,pingin,      NaN
# 4                                               ,hydgld,      NaN
# ...                                                  ...      ...
# 223516                                    ,seexc,coinba,      NaN
# 223517                       ,prital,orcle,kosco,hggngf,      NaN
# 223518                          ,qnbusa,qma,qbnk,qatfma,      NaN
# 223519                                          ,fstdun,      NaN
# 223520                                ,vngd,eqstry,bwth,      NaN
#
#                   company_codes_relevance_ticker_exchange
# 0              ,MMTOF:PSGM,7211:XTKS,MMTOY:PSGM,MMO:XFRA,
# 1                                                     NaN
# 2       ,INTU:XWBO,1INTU:XMIL,INTU:XNAS,INTU:XMEX,ITU:...
# 3       ,SGIOY:PSGM,SGIOF:PSGM,SH0:XFRA,SH00:XMUN,4507...
# 4                                                     NaN
# ...                                                   ...
# 223516                                                NaN
# 223517                                                NaN
# 223518                                                NaN
# 223519                                                NaN
# 223520                    ,EQS0:XETR,EQSTF:PSGM,EQS:XETR,
#
# [223521 rows x 42 columns]
