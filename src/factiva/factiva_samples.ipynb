# %%
import requests
import json
import pandas as pd
from time import sleep

user_key = "LKbI9fY6ZEPU8RcJUxQHjwKbld52WGt0"

base_url = "https://api.dowjones.com"
headers = {
    "user-key": user_key,
    "Content-Type": "application/json",
    "X-API-VERSION": "3.0"
}

def check_response(response):
    if response.status_code in [200, 201]:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# %%
def create_explain(query_body):
    """
    Create an explain request to check how many documents match a query
    """
    url = f"{base_url}/extractions/documents/_explain"
    response = requests.post(url, headers=headers, data=json.dumps(query_body))
    return check_response(response)

def check_explain_status(job_id):
    """
    Check the status of an explain job
    """
    url = f"{base_url}/extractions/documents/{job_id}/_explain"
    response = requests.get(url, headers=headers)
    return check_response(response)

def wait_for_explain_completion(job_id, max_retries=100, sleep_time=10):
    """
    Wait for an explain job to complete
    """
    for i in range(max_retries):
        status = check_explain_status(job_id)
        if not status:
            return None
            
        current_state = status['data']['attributes']['current_state']
        print(f"Current state: {current_state}")
        
        if current_state == "JOB_STATE_DONE":
            return status
        
        if i < max_retries - 1:
            print(f"Waiting {sleep_time} seconds...")
            sleep(sleep_time)
    
    print("Max retries reached. Job might still be running.")
    return None

# %%
divest_query = {
    "query": {
        "where": "language_code='en' AND publication_datetime >= '2015-01-01 00:00:00'",
        "includes": {
            "industry_codes": ["i82"]  # Financial services industry code
        },
    }
}

# # Add keywords related to divestment to the query
# divest_keywords = ["divestment", "divestiture", "divest", "non-core asset", 
#                   "portfolio simplification", "business simplification"]

# # Create a keyword condition using LIKE for the body field
# keyword_conditions = " OR ".join([f"body LIKE '%{keyword}%'" for keyword in divest_keywords])
# divest_query["query"]["where"] += f" AND ({keyword_conditions})"

# # Run the explain to see how many documents match
explain_result = create_explain(divest_query)

if explain_result:
    print("\nExplain job created:")
    print(f"Job ID: {explain_result['data']['id']}")
    
    # Wait for the explain job to complete
    job_id = explain_result['data']['id']
    final_status = wait_for_explain_completion(job_id)
    
    if final_status and 'counts' in final_status['data']['attributes']:
        count = final_status['data']['attributes']['counts']
        print(f"\nNumber of documents matching the query: {count}")
# Out:
# Explain job created:
# Job ID: b6f430d1-c624-4179-84f5-783a827ebf68

# %%
# Get a few sample documents to review
explain_job_id = "41f85d43-2267-410d-a70b-2b4bb290a416"
samples_url = f"https://api.dowjones.com/extractions/samples/{explain_job_id}?num_samples=5"
samples_response = requests.get(samples_url, headers=headers)
samples = samples_response.json()

# %%
samples
# Out:
# {'data': {'id': '41f85d43-2267-410d-a70b-2b4bb290a416',
#   'type': 'explain',
#   'attributes': {'counts': 5,
#    'current_state': 'JOB_STATE_DONE',
#    'sample': [{'an': 'SOLRADIN20190320ef3k005mt',
#      'company_codes': ',cndp,cndp,cndp,edf,',
#      'company_codes_about': ',edf,cndp,',
#      'company_codes_occur': ',cndp,',
#      'industry_codes': ',i16,i82,i82002,ieutil,ifinal,iutil,',
#      'ingestion_datetime': '2019-03-20T16:10:12.000Z',
#      'modification_datetime': '2019-03-20T16:10:12.000Z',
#      'publication_datetime': '2019-03-20T16:09:31.000Z',
#      'availability_datetime': '2019-03-20T17:40:26.360Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',uk,italy,eecz,eurz,medz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',c151,c15,ccat,ncat,nfact,nfcpin,',
#      'title': 'RTE FY net 603 mln eur, up 62%',
#      'word_count': 145,
#      'newswires_codes': '',
#      'restrictor_codes': ',FSPNORMAWS0300,SOLRADIN,fspFileId430732880,FUT,CLNTALL,EN,EUR,IFINAL,IINV,ITALY,MEDZ,SFSOLE,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLD,WEURZ,djrcef,MPCV1M13M0B1,MPCEnvPROD,MPCDocHashDE86AFADD269A8F5,FSPTHINGFINDER,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOOC,FSP2YESCOCOMOC,FSPRBC,FSPRBCCO,FSPRBCCOM,FSP2YESIN,FSPRBCNS,FSP2YESNS,FSPCATEGORIZER,FSPCATRE,FSP2YESRE,FSP2NOPEOC,FSPRBC613236,FSPRBC615037,FSPRBC818182,MPCCL,MPCJP,MPCKW,MPCKP,MPCESRE,MPCESIN,MPCESNS,FSP2AC,'},
#     {'an': 'SOLRADIN20211109ehb9001b9',
#      'company_codes': ',abf,dlip,abf,abf,byer,byer,dlip,dlip,fergmo,fergmo,mrg,mrg,porsch,porsch,whoz,whoz,wittin,',
#      'company_codes_about': ',dlip,abf,',
#      'company_codes_occur': ',whoz,porsch,mrg,fergmo,dlip,byer,abf,',
#      'industry_codes': ',i41,i82,i82003,icnp,ifinal,ifood,',
#      'ingestion_datetime': '2021-11-09T08:42:26.000Z',
#      'modification_datetime': '2021-11-09T08:42:26.000Z',
#      'publication_datetime': '2021-11-09T08:42:00.000Z',
#      'availability_datetime': '2021-11-09T10:12:43.898Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',gfr,eurz,usa,dach,eecz,namz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',m11,mcat,e1103,nrmf,e11,ecat,ncat,nfact,nfce,niwe,',
#      'title': 'Europe shares open little changed ahead of US inflation data',
#      'word_count': 339,
#      'newswires_codes': '',
#      'restrictor_codes': ',FSPNORMAWS0400,SOLRADIN,fspFileId186485570,FUT,CLNTALL,EN,EUR,IFINAL,IINV,ITALY,MEDZ,SFSOLE,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,MPCV1M20M0B1,MPCEnvPROD,MPCDocHashB5C8C94D73126FB1,FSPTHINGFINDER,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOOC,FSP2YESCOCOMOC,FSP2YESCOORGOC,FSP2YESIN,FSPCATEGORIZER,FSPCATNS,FSPRBC,FSPRBCNS,FSP2YESNS,FSPCATRE,FSP2YESRE,FSPRBCRE,FSP2NOPEOC,FSPRBC182991,FSPRBC257741,FSPRBC621478,FSPRBC718922,FSPRBC823202,FSPRBC874229,MPCCL,MPCJP,MPCKW,MPCKP,MPCESRE,MPCESIN,MPCESNS,FSP2AC,FSP2ACRBCTERA,FSP2ACRBCPRTY,'},
#     {'an': 'SOLRADIN20180329ee3t004ed',
#      'company_codes': ',aqrcml,astalt,azmt,brdgai,casgen,mwacel,akocal,akocal,aqrcml,aqrcml,astalt,astalt,azmt,azmt,banqnp,banqnp,bccnls,bccnls,bcmlp,bcmlp,bpmiln,bpmiln,bpus,bpus,brdgai,brdgai,cafunm,cafunm,casgen,casgen,cgfr,cgfr,cqsul,cqsul,crdto,crdto,dscvcz,dscvcz,enel,enel,ennfml,ennfml,fergmo,fergmo,finbfs,finbfs,glglp,glglp,gsacpl,gsacpl,hbkcm,hbkcm,hgil,hgil,itlgs,itlgs,jpmfam,jpmfam,mairtc,mairtc,mcrmat,mcrmat,mdset,mdset,medbn,medbn,mwacel,mwacel,nvoamb,nvoamb,ocecml,ocecml,olidat,olidat,olivet,olivet,olvtsp,olvtsp,prital,prital,sacip,sacip,saflit,saflit,saii,saii,saipm,saipm,schiml,schiml,sgfi,sgfi,snaret,snaret,tens,tens,unicm,unicm,wadvil,wadvil,wmil,wmil,aszngn,bpus,enel,eni,erg,mdset,medbn,nvoamb,olivet,sifait,snaret,tens,terna,rocagu,squit,tecgr,',
#      'company_codes_about': ',terna,tens,snaret,sifait,olivet,nvoamb,medbn,mdset,erg,eni,enel,bpus,aszngn,mwacel,casgen,brdgai,azmt,astalt,aqrcml,',
#      'company_codes_occur': ',wmil,wadvil,unicm,tens,snaret,sgfi,schiml,saipm,saii,saflit,sacip,prital,olvtsp,olivet,olidat,ocecml,nvoamb,mwacel,medbn,mdset,mcrmat,mairtc,jpmfam,itlgs,hgil,hbkcm,gsacpl,glglp,finbfs,fergmo,ennfml,enel,dscvcz,crdto,cqsul,cgfr,casgen,cafunm,brdgai,bpus,bpmiln,bcmlp,bccnls,banqnp,azmt,astalt,aqrcml,akocal,',
#      'industry_codes': ',i1,i13,i16,i16101,i16102,i162,i163,i22,i222,i364,i502,i7902,i79026,i814,i81402,i81502,i82,i82001,i831,i83101,i83102,i83107,i83108,i97411,i9741102,i974110202,iaer,ialtinv,ibasicm,ibnk,iconst,icre,ieutil,ifinal,ihedge,iindstrls,iinv,iioil,imed,iutil,',
#      'ingestion_datetime': '2018-03-29T14:44:47.000Z',
#      'modification_datetime': '2018-03-29T14:44:47.000Z',
#      'publication_datetime': '2018-03-29T14:43:11.000Z',
#      'availability_datetime': '2018-03-29T16:15:11.990Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',italy,eecz,eurz,medz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',ntab,c13,ccat,ncat,nfact,nfce,nfcpin,niwe,',
#      'title': 'Consob: Net short positions in securities Equity',
#      'word_count': 1079,
#      'newswires_codes': '',
#      'restrictor_codes': ',FSPNORMAWS0300,SOLRADIN,fspFileId278592194,FUT,CLNTALL,EN,EUR,IFINAL,IINV,ITALY,MEDZ,SFSOLE,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLD,WEURZ,djsbex,tboiler,MPCV1M9M1B1,MPCEnvPROD,MPCDocHash446780CF19EE459D,FSPTHINGFINDER,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOOC,FSP2YESCOCOMOC,FSPRBC,FSPRBCCO,FSPRBCCOM,FSP2YESIN,FSPRBCNS,FSP2YESNS,FSPRBCRE,FSP2YESRE,FSP2NOPEOC,FSPRBC670468,FSPRBC670473,FSPRBC670474,FSPRBC670475,FSPRBC670477,FSPRBC670479,FSPRBC670480,FSPRBC670483,FSPRBC670484,FSPRBC670488,FSPRBC670490,FSPRBC670491,FSPRBC670492,FSPRBC702889,FSPRBC718119,FSPRBC805679,FSPRBC805751,FSPRBC833800,FSPRBC850883,MPCCL,MPCJP,MPCKW,MPCKP,MPCESRE,MPCESIN,MPCESNS,FSP2AC,'},
#     {'an': 'SOLRADIN20160811ec8b001xr',
#      'company_codes': ',szrat,omtl,omtl,preus,preus,szrat,szrat,thyssn,thyssn,',
#      'company_codes_about': ',szrat,',
#      'company_codes_occur': ',thyssn,szrat,preus,omtl,',
#      'industry_codes': ',i82,i82002,ifinal,',
#      'ingestion_datetime': '2016-08-11T11:43:21.000Z',
#      'modification_datetime': '2016-08-11T11:43:21.000Z',
#      'publication_datetime': '2016-08-11T11:43:01.000Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',usa,gfr,switz,dach,eecz,eurz,namz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',m11,nrmf,mcat,ncat,nfact,nfce,niwe,',
#      'title': 'Europe shares reverse losses, trade mostly higher',
#      'word_count': 244,
#      'newswires_codes': '',
#      'restrictor_codes': ',FSPNORMAWS0300,SOLRADIN,fspFileId31670641,FUT,CLNTALL,EN,EUR,IFINAL,IINV,ITALY,MEDZ,SFSOLE,TCUWIR,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLD,WEURZ,MPCV1M0M0B196,MPCEnvPROD,MPCDocHashE8567E53883BE4E0,FSPTHINGFINDER,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOOC,FSP2YESCOCOMOC,FSP2YESIN,FSPCATEGORIZER,FSPSDXNS,FSP2YESNS,FSPRBC,FSPRBCNS,FSPCATRE,FSP2YESRE,FSP2NOPEOC,FSPRBC718922,FSPCVG,MPCJP,MPCKW,MPCKP,MPCESREFail,FSP2AC,'},
#     {'an': 'SOLRADIN20181204eec4004mp',
#      'company_codes': ',astalt,azmt,mwacel,scptal,aclios,aclios,akocal,akocal,aqrcml,aqrcml,astalt,astalt,azmt,azmt,bccnls,bccnls,bcgeni,bcgeni,bpmiln,bpmiln,bpus,bpus,cafunm,cafunm,cgfr,cgfr,cinveb,cinveb,deshaw,deshaw,dscvcz,dscvcz,enfimi,enfimi,ennfml,ennfml,fergmo,fergmo,glglp,glglp,gsacpl,gsacpl,hbkcm,hbkcm,ifisi,ifisi,itlgs,itlgs,jpmfam,jpmfam,lansdn,lansdn,lninml,lninml,mairtc,mairtc,mwacel,mwacel,ocecml,ocecml,olidat,olidat,olivet,olivet,olvtsp,olvtsp,omamul,omamul,postit,postit,rentc,rentc,ricf,ricf,rullc,rullc,saflit,saflit,saii,saii,saipm,saipm,scptal,scptal,tens,tens,unicm,unicm,wadvil,wadvil,wmtdp,wmtdp,aszngn,autsd,bpus,erg,olivet,sifait,tens,terna,bene,gbenet,rocagu,squit,tecgr,',
#      'company_codes_about': ',terna,tens,sifait,olivet,erg,bpus,autsd,aszngn,scptal,mwacel,azmt,astalt,',
#      'company_codes_occur': ',wmtdp,wadvil,unicm,tens,scptal,saipm,saii,saflit,rullc,ricf,rentc,postit,omamul,olvtsp,olivet,olidat,ocecml,mwacel,mairtc,lninml,lansdn,jpmfam,itlgs,ifisi,hbkcm,gsacpl,glglp,fergmo,ennfml,enfimi,dscvcz,deshaw,cinveb,cgfr,cafunm,bpus,bpmiln,bcgeni,bccnls,azmt,astalt,aqrcml,akocal,aclios,',
#      'industry_codes': ',i1,i13,i16,i16102,i22,i222,i364,i502,i7902,i79026,i814,i81402,i82,i82001,i831,i83102,i83107,iaer,ibasicm,ibcs,ibnk,iconst,icre,ieutil,ifinal,iindstrls,iinv,iioil,irailtr,irdops,itsp,iutil,',
#      'ingestion_datetime': '2018-12-04T15:08:22.000Z',
#      'modification_datetime': '2018-12-04T15:08:22.000Z',
#      'publication_datetime': '2018-12-04T15:06:51.000Z',
#      'availability_datetime': '2018-12-04T16:39:49.118Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',italy,eecz,eurz,medz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',ccat,ntab,ncat,nfact,nfce,niwe,',
#      'title': 'Consob: Net short positions in securities Equity',
#      'word_count': 989,
#      'newswires_codes': '',
#      'restrictor_codes': ',FSPNORMAWS0300,SOLRADIN,fspFileId385539651,FUT,CLNTALL,EN,EUR,IFINAL,IINV,ITALY,MEDZ,SFSOLE,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLD,WEURZ,djsbex,tboiler,MPCV1M12M0B1,MPCEnvPROD,MPCDocHashBF951EF53E4E479E,FSPTHINGFINDER,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOOC,FSP2YESCOCOMOC,FSPRBC,FSPRBCCO,FSPRBCCOM,FSP2YESIN,FSPCATEGORIZER,FSPCATNS,FSPRBCNS,FSP2YESNS,FSPRBCRE,FSP2YESRE,FSP2NOPEOC,FSPRBC670466,FSPRBC670468,FSPRBC670475,FSPRBC670477,FSPRBC670479,FSPRBC670490,FSPRBC670491,FSPRBC670492,FSPRBC702889,FSPRBC718119,FSPRBC805751,FSPRBC833800,FSPRBC850883,MPCCL,MPCJP,MPCKW,MPCKP,MPCESRE,MPCESIN,MPCESNS,FSP2AC,'}]}},
#  'links': {'self': 'https://api.dowjones.com/extractions/samples/41f85d43-2267-410d-a70b-2b4bb290a416'}}
