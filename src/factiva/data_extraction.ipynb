# %% [markdown]
# ## Extracting articles metadata without downloading its content
# * use keywords and industry codes discussed with Sophie
# * check possibility and limits of Snapshots API

# %%
import requests
import json
import logging
import os
from pprint import pprint
from time import sleep, time


user_key = "LKbI9fY6ZEPU8RcJUxQHjwKbld52WGt0"

base_url = "https://api.dowjones.com"
headers = {
    "user-key": user_key,
    "Content-Type": "application/json",
    "X-API-VERSION": "3.0"
}
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

def check_response(response):
    if response.status_code in [200, 201]:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# %%
def create_explain(query_body):
    """
    Create an explain request to check how many documents match a query
    """
    url = f"{base_url}/extractions/documents/_explain"
    response = requests.post(url, headers=headers, data=json.dumps(query_body))
    return check_response(response)

def check_explain_status(job_id):
    """
    Check the status of an explain job
    """
    url = f"{base_url}/extractions/documents/{job_id}/_explain"
    response = requests.get(url, headers=headers)
    return check_response(response)

def wait_for_explain_completion(job_id, max_retries=100, sleep_time=10):
    """
    Wait for an explain job to complete
    """
    for i in range(max_retries):
        status = check_explain_status(job_id)
        if not status:
            return None
            
        current_state = status['data']['attributes']['current_state']
        print(f"Current state: {current_state}")
        
        if current_state == "JOB_STATE_DONE":
            return status
        
        if i < max_retries - 1:
            print(f"Waiting {sleep_time} seconds...")
            sleep(sleep_time)
    
    print("Max retries reached. Job might still be running.")
    return None

def run_explain(input_query, num_samples=5):
    explain_result = create_explain(input_query)

    if explain_result:
        print("\nExplain job created:")
        print(f"Job ID: {explain_result['data']['id']}")
        
        job_id = explain_result['data']['id']
        final_status = wait_for_explain_completion(job_id)

        print(f"\nGetting samples for job ID: {job_id}")
        if final_status and 'counts' in final_status['data']['attributes']:
            count = final_status['data']['attributes']['counts']
            print(f"\nNumber of documents matching the query: {count}")
            
            
            samples_url = f"https://api.dowjones.com/extractions/samples/{job_id}?num_samples={num_samples}"
            samples_response = requests.get(samples_url, headers=headers)
            samples = samples_response.json()
            pprint(samples,compact=True)
            return final_status, samples

# %%
def create_extraction(query_body):
    """
    Submit a new Snapshot Extraction job.
    Endpoint: POST /extractions/documents {@link Postman Snapshots API}  [oai_citation:4‡Postman API Platform](https://www.postman.com/dj-cse/dow-jones-apis/documentation/l9tpql6/factiva-apis?entity=request-25580757-cd7e1b1f-a2a7-4a41-87fa-adfb6c3ff58a&utm_source=chatgpt.com)
    """
    url = f"{base_url}/extractions/documents"
    logging.info("Creating extraction job...")
    resp = requests.post(url, headers=headers, json=query_body)
    data = check_response(resp)
    job_id = data['data']['id']
    logging.info(f"Extraction job created: {job_id}")
    return job_id


def check_extraction_status(job_id):
    """
    Retrieve the current state of an extraction job.
    Endpoint: GET /extractions/documents/{job_id}  [oai_citation:5‡Postman API Platform](https://www.postman.com/dj-cse/dow-jones-apis/documentation/l9tpql6/factiva-apis?entity=request-25580757-cd7e1b1f-a2a7-4a41-87fa-adfb6c3ff58a&utm_source=chatgpt.com)
    """
    url = f"{base_url}/extractions/documents/{job_id}"
    resp = requests.get(url, headers=headers)
    return check_response(resp)

def wait_for_extraction_completion(job_id, max_retries=60, initial_sleep=10):
    """
    Poll the extraction job until it reaches JOB_STATE_DONE or JOB_STATE_FAILED.
    Uses exponential back-off to avoid hammering the API.
    """
    sleep_time = initial_sleep
    for attempt in range(1, max_retries + 1):
        status = check_extraction_status(job_id)
        state = status['data']['attributes']['current_state']
        logging.info(f"[Attempt {attempt}/{max_retries}] State: {state}")
        if state == "JOB_STATE_DONE":
            return status['data']['attributes']
        if state == "JOB_STATE_FAILED":
            detail = status['errors'][0].get('detail', 'No detail provided')
            raise RuntimeError(f"Extraction job {job_id} failed: {detail}")
        logging.info(f"Sleeping for {sleep_time}s before retry...")
        sleep(sleep_time)
        sleep_time = min(sleep_time * 1.5, 300)  # cap back-off at 5 minutes
    raise TimeoutError(f"Job {job_id} did not complete after {max_retries} attempts.")

def download_files(files, snapshot_id, target_root="../../extractions"):
    """
    Stream-download each file URI into ../../extractions/{snapshot_id}/.
    Ensures atomic writes and retries on transient errors.  [oai_citation:6‡factiva-news-python.readthedocs.io](https://factiva-news-python.readthedocs.io/en/latest/factiva.news/snapshot.html?utm_source=chatgpt.com)
    """
    download_dir = os.path.abspath(os.path.join(target_root, snapshot_id))
    os.makedirs(download_dir, exist_ok=True)
    logging.info(f"Downloading {len(files)} files into '{download_dir}'")

    for file_meta in files:
        uri = file_meta["uri"]
        file_name = os.path.basename(uri)
        dest_path = os.path.join(download_dir, file_name)
        logging.info(f"-> Downloading {file_name}")

        # Attempt download with up to 3 retries
        for attempt in range(1, 4):
            try:
                with requests.get(uri, headers=headers, stream=True, timeout=120) as r:
                    r.raise_for_status()
                    with open(dest_path + ".tmp", "wb") as tmpf:
                        for chunk in r.iter_content(chunk_size=8192):
                            if chunk:
                                tmpf.write(chunk)
                # Atomic rename on success
                os.replace(dest_path + ".tmp", dest_path)
                logging.info(f"   Saved to {dest_path}")
                break
            except Exception as e:
                logging.warning(f"   Attempt {attempt}/3 failed: {e}")
                if attempt == 3:
                    logging.error(f"   Giving up on {file_name}")
                    raise
                sleep(5 * attempt)

def run_extraction(query_body):
    """
    Full end-to-end extraction: submit job, wait, download files.
    """
    job_id = create_extraction(query_body)
    attrs = wait_for_extraction_completion(job_id)
    files = attrs.get("files", [])
    if not files:
        logging.warning(f"No files found for job {job_id}")
    else:
        download_files(files, job_id)
    logging.info(f"Extraction {job_id} complete.")
    return job_id

# %% [markdown]
# ### Making explain queries
# v0: ton of keywords and industries - leads to lot of irrelevant stuff

# %%
industry_codes = [
    "i814", "i815", "i82", "i831", "iabls", "ialtinv", "ibnk", "ibusdev", "icaslty", 
    "ichalbk", "iclins", "icrowfd", "iextrfu", "ifinal", "ifmsoft", "igovspon", 
    "ihedge", "iibnk", "iinsurt", "iinv", "ipension", "iplastic", "ippf", "ipricr", 
    "iprivhea", "irbank", "iresinv", "isover", "iventure", "iwealth"
]

data_providers_industry_codes = ["i8395463", "ifinal", "iplastic", "i83102","i83109","iadmin"]

industry_codes.extend(data_providers_industry_codes)
industry_codes = list(set(industry_codes))  # Remove duplicates

carveout_keywords = [
    "portfolio", "strategic actions",
    "review of strategic alternatives", "divestment", "divestiture", "divest", 
    "divesting", "disposal", "non-core asset", "focus on core assets", 
    "refocus on core assets", "reduce leverage", "improve liquidity", 
    "bonds maturing", "notes maturing", "debt maturing", "rationalize costs",
    "restructuring program", "in talks to divest", "capital return",
    "special dividend",  "simplification",   
    "carve-out", "spin-off", "strategic review", "portfolio optimization",
    "asset sale", "streamline operations", "exit markets", "discontinue operations",
    "strategic disposal", "non-strategic assets", "shed assets", "optimize footprint",
    "new CEO", "management change", "leadership change", "new management team",
    #TODO: add more keywords related to legal, management, strategy
]

keyword_conditions = " OR ".join([f"body LIKE '%{keyword}%'" for keyword in carveout_keywords])

query = {
    "query": {
        "where": f"language_code='en' AND publication_datetime >= '2024-05-01 00:00:00' AND ({keyword_conditions})",
        "includes": {
            "industry_codes": industry_codes,
            "region_codes": ["eurz"]
        },
    }
}

run_explain(query)
# Out:
# Explain job created:
# Job ID: aaa2379e-49c3-43d8-9636-17d76fbdb689
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_DONE
#
# Getting samples for job ID: aaa2379e-49c3-43d8-9636-17d76fbdb689
#
# Number of documents matching the query: 813808
# {'data': {'attributes': {'counts': 5,
#                          'current_state': 'JOB_STATE_DONE',
#                          'sample': [{'an': 'OHFSEC0020240724ek7n00001',
#                                      'company_codes': '',
#                                      'company_codes_about': '',
#                                      'company_codes_occur': '',
#                                      'industry_codes': ',i814,i81402,ibnk,ifinal,',
#                                      'ingestion_datetime': '2024-07-24T00:30:08.000Z',
#                                      'modification_datetime': '2024-07-24T00:30:08.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2024-07-23T00:00:00.000Z',
#                                      'publisher_name': 'Brownstein & Egusa',
#                                      'region_codes': '',
#                                      'region_of_origin': 'EEURZ EUR HUNG ',
#                                      'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOCOOC,FSP2NORE,FSP2YESIN,FSP2YESNS,FSP2YESPEOC,FSPCATEGORIZER,FSPCATIN,FSPCATNS,fspFileId573692323,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC843936,FSPRBC880024,FSPRBCGROUP11097,FSPRBCGROUP188,FSPRBCNS,FSPRBCNSCENTRP,FUTA,MPCCL,MPCDocHash27065AB5E99343A2,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,tnomci,TSCH,TTRK,TYAS,TYLD,',
#                                      'source_code': 'OHFSEC',
#                                      'source_name': '150sec',
#                                      'subject_codes': ',c13,ccat,centrp,csmlbs,ncat,nfact,nfcpex,nfcpin,',
#                                      'title': 'Infinant revolutionizes banking '
#                                               'with its smart growth platform',
#                                      'word_count': 518},
#                                     {'an': 'SOLRADIN20250326el3q000xd',
#                                      'company_codes': ',fndven,fndven,fndven,forin,nbg,nbg,nbg,sftbnk,stbgrg,stbgrg,',
#                                      'company_codes_about': ',nbg,fndven,',
#                                      'company_codes_occur': ',stbgrg,nbg,fndven,',
#                                      'industry_codes': ',i814,i81402,i81501,ibnk,ifinal,',
#                                      'ingestion_datetime': '2025-03-26T09:23:47.000Z',
#                                      'modification_datetime': '2025-03-26T09:23:47.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2025-03-26T09:23:00.000Z',
#                                      'publisher_name': 'Il Sole 24 Ore SpA',
#                                      'region_codes': ',balkz,devgcoz,eecz,eurz,greece,medz,',
#                                      'region_of_origin': 'EUR ITALY MEDZ '
#                                                          'WEURZ ',
#                                      'restrictor_codes': ',CLNTALL,CTGAIIE,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESCOORGOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATRE,fspFileId665491149,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621565,FSPRBC730823,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCNS,FSPRBCNSC173,FSPRBCRE,FSPRBCREGREECE,FSPTHINGFINDER,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash2AA49242B24098C8,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,',
#                                      'source_code': 'SOLRADIN',
#                                      'source_name': '24 Ore Radiocor-Newswire '
#                                                     'International Edition',
#                                      'subject_codes': ',c17,c173,ccat,ncat,nfact,nfcpin,',
#                                      'title': 'DoValue inks 0.7 bln eur '
#                                               'securitization servicing deal '
#                                               'with National Bank of Greece',
#                                      'word_count': 197},
#                                     {'an': 'SOLRADIN20240628ek6s002ut',
#                                      'company_codes': ',amchso,cinii,cinii,comtn,comtn,delhhg,delhhg,eni,eni,fincan,fincan,isbtms,isbtms,sg,sg,sodfor,sodfor,syield,syield,wlgrn,wlgrn,',
#                                      'company_codes_about': '',
#                                      'company_codes_occur': ',wlgrn,syield,sodfor,sg,isbtms,fincan,eni,delhhg,comtn,cinii,',
#                                      'industry_codes': '',
#                                      'ingestion_datetime': '2024-06-28T08:06:01.000Z',
#                                      'modification_datetime': '2024-06-28T08:06:01.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2024-06-28T08:05:00.000Z',
#                                      'publisher_name': 'Il Sole 24 Ore SpA',
#                                      'region_codes': ',eecz,eurz,fra,medz,weurz,',
#                                      'region_of_origin': 'EUR ITALY MEDZ '
#                                                          'WEURZ ',
#                                      'restrictor_codes': ',CLNTALL,CTGAIIE,djsbex,EN,EUR,FSP2NOCO,FSP2NOIN,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId563309796,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC718119,FSPRBC894240,FSPRBCGROUP11203,FSPRBCGROUP6835,FSPRBCNS,FSPRBCNSNLIST,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash7388D92848E34141,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,',
#                                      'source_code': 'SOLRADIN',
#                                      'source_name': '24 Ore Radiocor-Newswire '
#                                                     'International Edition',
#                                      'subject_codes': ',c18,cactio,ccat,cdiv,e11,e1101,ecat,ncat,nfact,nfce,nfcpin,niwe,nlist,nrgn,',
#                                      'title': 'Newspaper headline roundup',
#                                      'word_count': 327},
#                                     {'an': 'SOLRADIN20241121ekbl0025t',
#                                      'company_codes': '',
#                                      'company_codes_about': '',
#                                      'company_codes_occur': '',
#                                      'industry_codes': '',
#                                      'ingestion_datetime': '2024-11-21T10:05:19.000Z',
#                                      'modification_datetime': '2025-01-25T11:55:39.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2024-11-21T10:05:00.000Z',
#                                      'publisher_name': 'Il Sole 24 Ore SpA',
#                                      'region_codes': ',eecz,eurz,italy,medz,weurz,',
#                                      'region_of_origin': 'EUR ITALY MEDZ '
#                                                          'WEURZ ',
#                                      'restrictor_codes': ',CLNTALL,CTGAIIE,djrcef,EN,EUR,FSP2NOCO,FSP2NOCOOC,FSP2NOIN,FSP2NOPEOC,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATRE,fspFileId621060102,fspFileId643376837,FSPMUAUTO,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC626655,FSPRBC818182,FSPRBCGROUP10933,FSPRBCGROUP8095,FSPRBCNS,FSPRBCNSC1512,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash05F251A63D4EE6AA,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,',
#                                      'source_code': 'SOLRADIN',
#                                      'source_name': '24 Ore Radiocor-Newswire '
#                                                     'International Edition',
#                                      'subject_codes': ',c15,c151,c1512,cactio,ccat,ncat,nfact,nfce,nfcpin,',
#                                      'title': 'IGD sees 2027 funds from '
#                                               'operations 48 mln eur, up 41% '
#                                               'vs 2024',
#                                      'word_count': 261},
#                                     {'an': 'SOLRADIN20250402el42005bp',
#                                      'company_codes': ',fiic,fiic,fiic,teslmi,teslmi,',
#                                      'company_codes_about': ',fiic,',
#                                      'company_codes_occur': ',teslmi,fiic,',
#                                      'industry_codes': ',i351,i35104,i82,iaut,ifinal,',
#                                      'ingestion_datetime': '2025-04-02T17:15:30.000Z',
#                                      'modification_datetime': '2025-04-02T17:15:30.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2025-04-02T17:15:00.000Z',
#                                      'publisher_name': 'Il Sole 24 Ore SpA',
#                                      'region_codes': ',eecz,eurz,nordz,swed,',
#                                      'region_of_origin': 'EUR ITALY MEDZ '
#                                                          'WEURZ ',
#                                      'restrictor_codes': ',CLNTALL,CTGAIIE,djrcef,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,fspFileId668716696,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621458,FSPRBC818182,FSPRBC820806,FSPRBC838785,FSPRBCGROUP10933,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCGROUP6775,FSPRBCIN,FSPRBCINI35104,FSPRBCNS,FSPRBCNSC181,FSPRBCRE,FSPRBCRESWED,FSPTHINGFINDER,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHashE6306DA13D01735E,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,',
#                                      'source_code': 'SOLRADIN',
#                                      'source_name': '24 Ore Radiocor-Newswire '
#                                                     'International Edition',
#                                      'subject_codes': ',c1511,c18,c181,c41,cactio,ccat,ncat,nfact,nfcpin,',
#                                      'title': "Sweden's Folksam sells Tesla "
#                                               "stake on approach to workers' "
#                                               'rights',
#                                      'word_count': 181}]},
#           'id': 'aaa2379e-49c3-43d8-9636-17d76fbdb689',
#           'type': 'explain'},
#  'links': {'self': 'https://api.dowjones.com/extractions/samples/aaa2379e-49c3-43d8-9636-17d76fbdb689'}}
# ({'data': {'id': 'aaa2379e-49c3-43d8-9636-17d76fbdb689',
#    'type': 'explain',
#    'attributes': {'counts': 813808, 'current_state': 'JOB_STATE_DONE'}},
#   'links': {'self': 'https://api.dowjones.com/extractions/documents/aaa2379e-49c3-43d8-9636-17d76fbdb689/_explain'}},
#  {'data': {'id': 'aaa2379e-49c3-43d8-9636-17d76fbdb689',
#    'type': 'explain',
#    'attributes': {'counts': 5,
#     'current_state': 'JOB_STATE_DONE',
#     'sample': [{'an': 'OHFSEC0020240724ek7n00001',
#       'company_codes': '',
#       'company_codes_about': '',
#       'company_codes_occur': '',
#       'industry_codes': ',i814,i81402,ibnk,ifinal,',
#       'ingestion_datetime': '2024-07-24T00:30:08.000Z',
#       'modification_datetime': '2024-07-24T00:30:08.000Z',
#       'publication_datetime': '2024-07-23T00:00:00.000Z',
#       'publisher_name': 'Brownstein & Egusa',
#       'region_codes': '',
#       'region_of_origin': 'EEURZ EUR HUNG ',
#       'source_code': 'OHFSEC',
#       'source_name': '150sec',
#       'subject_codes': ',c13,ccat,centrp,csmlbs,ncat,nfact,nfcpex,nfcpin,',
#       'title': 'Infinant revolutionizes banking with its smart growth platform',
#       'word_count': 518,
#       'newswires_codes': '',
#       'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOCOOC,FSP2NORE,FSP2YESIN,FSP2YESNS,FSP2YESPEOC,FSPCATEGORIZER,FSPCATIN,FSPCATNS,fspFileId573692323,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC843936,FSPRBC880024,FSPRBCGROUP11097,FSPRBCGROUP188,FSPRBCNS,FSPRBCNSCENTRP,FUTA,MPCCL,MPCDocHash27065AB5E99343A2,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,tnomci,TSCH,TTRK,TYAS,TYLD,'},
#      {'an': 'SOLRADIN20250326el3q000xd',
#       'company_codes': ',fndven,fndven,fndven,forin,nbg,nbg,nbg,sftbnk,stbgrg,stbgrg,',
#       'company_codes_about': ',nbg,fndven,',
#       'company_codes_occur': ',stbgrg,nbg,fndven,',
#       'industry_codes': ',i814,i81402,i81501,ibnk,ifinal,',
#       'ingestion_datetime': '2025-03-26T09:23:47.000Z',
#       'modification_datetime': '2025-03-26T09:23:47.000Z',
#       'publication_datetime': '2025-03-26T09:23:00.000Z',
#       'publisher_name': 'Il Sole 24 Ore SpA',
#       'region_codes': ',balkz,devgcoz,eecz,eurz,greece,medz,',
#       'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#       'source_code': 'SOLRADIN',
#       'source_name': '24 Ore Radiocor-Newswire International Edition',
#       'subject_codes': ',c17,c173,ccat,ncat,nfact,nfcpin,',
#       'title': 'DoValue inks 0.7 bln eur securitization servicing deal with National Bank of Greece',
#       'word_count': 197,
#       'newswires_codes': '',
#       'restrictor_codes': ',CLNTALL,CTGAIIE,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESCOORGOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATRE,fspFileId665491149,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621565,FSPRBC730823,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCNS,FSPRBCNSC173,FSPRBCRE,FSPRBCREGREECE,FSPTHINGFINDER,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash2AA49242B24098C8,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,'},
#      {'an': 'SOLRADIN20240628ek6s002ut',
#       'company_codes': ',amchso,cinii,cinii,comtn,comtn,delhhg,delhhg,eni,eni,fincan,fincan,isbtms,isbtms,sg,sg,sodfor,sodfor,syield,syield,wlgrn,wlgrn,',
#       'company_codes_about': '',
#       'company_codes_occur': ',wlgrn,syield,sodfor,sg,isbtms,fincan,eni,delhhg,comtn,cinii,',
#       'industry_codes': '',
#       'ingestion_datetime': '2024-06-28T08:06:01.000Z',
#       'modification_datetime': '2024-06-28T08:06:01.000Z',
#       'publication_datetime': '2024-06-28T08:05:00.000Z',
#       'publisher_name': 'Il Sole 24 Ore SpA',
#       'region_codes': ',eecz,eurz,fra,medz,weurz,',
#       'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#       'source_code': 'SOLRADIN',
#       'source_name': '24 Ore Radiocor-Newswire International Edition',
#       'subject_codes': ',c18,cactio,ccat,cdiv,e11,e1101,ecat,ncat,nfact,nfce,nfcpin,niwe,nlist,nrgn,',
#       'title': 'Newspaper headline roundup',
#       'word_count': 327,
#       'newswires_codes': '',
#       'restrictor_codes': ',CLNTALL,CTGAIIE,djsbex,EN,EUR,FSP2NOCO,FSP2NOIN,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId563309796,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC718119,FSPRBC894240,FSPRBCGROUP11203,FSPRBCGROUP6835,FSPRBCNS,FSPRBCNSNLIST,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash7388D92848E34141,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,'},
#      {'an': 'SOLRADIN20241121ekbl0025t',
#       'company_codes': '',
#       'company_codes_about': '',
#       'company_codes_occur': '',
#       'industry_codes': '',
#       'ingestion_datetime': '2024-11-21T10:05:19.000Z',
#       'modification_datetime': '2025-01-25T11:55:39.000Z',
#       'publication_datetime': '2024-11-21T10:05:00.000Z',
#       'publisher_name': 'Il Sole 24 Ore SpA',
#       'region_codes': ',eecz,eurz,italy,medz,weurz,',
#       'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#       'source_code': 'SOLRADIN',
#       'source_name': '24 Ore Radiocor-Newswire International Edition',
#       'subject_codes': ',c15,c151,c1512,cactio,ccat,ncat,nfact,nfce,nfcpin,',
#       'title': 'IGD sees 2027 funds from operations 48 mln eur, up 41% vs 2024',
#       'word_count': 261,
#       'newswires_codes': '',
#       'restrictor_codes': ',CLNTALL,CTGAIIE,djrcef,EN,EUR,FSP2NOCO,FSP2NOCOOC,FSP2NOIN,FSP2NOPEOC,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATRE,fspFileId621060102,fspFileId643376837,FSPMUAUTO,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC626655,FSPRBC818182,FSPRBCGROUP10933,FSPRBCGROUP8095,FSPRBCNS,FSPRBCNSC1512,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash05F251A63D4EE6AA,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,'},
#      {'an': 'SOLRADIN20250402el42005bp',
#       'company_codes': ',fiic,fiic,fiic,teslmi,teslmi,',
#       'company_codes_about': ',fiic,',
#       'company_codes_occur': ',teslmi,fiic,',
#       'industry_codes': ',i351,i35104,i82,iaut,ifinal,',
#       'ingestion_datetime': '2025-04-02T17:15:30.000Z',
#       'modification_datetime': '2025-04-02T17:15:30.000Z',
#       'publication_datetime': '2025-04-02T17:15:00.000Z',
#       'publisher_name': 'Il Sole 24 Ore SpA',
#       'region_codes': ',eecz,eurz,nordz,swed,',
#       'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#       'source_code': 'SOLRADIN',
#       'source_name': '24 Ore Radiocor-Newswire International Edition',
#       'subject_codes': ',c1511,c18,c181,c41,cactio,ccat,ncat,nfact,nfcpin,',
#       'title': "Sweden's Folksam sells Tesla stake on approach to workers' rights",
#       'word_count': 181,
#       'newswires_codes': '',
#       'restrictor_codes': ',CLNTALL,CTGAIIE,djrcef,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,fspFileId668716696,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621458,FSPRBC818182,FSPRBC820806,FSPRBC838785,FSPRBCGROUP10933,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCGROUP6775,FSPRBCIN,FSPRBCINI35104,FSPRBCNS,FSPRBCNSC181,FSPRBCRE,FSPRBCRESWED,FSPTHINGFINDER,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHashE6306DA13D01735E,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,'}]}},
#   'links': {'self': 'https://api.dowjones.com/extractions/samples/aaa2379e-49c3-43d8-9636-17d76fbdb689'}})

# %% [markdown]
# ### Version 1: intent+action for future-oriented search

# %%
action_tags = [
  "%cactio%", "%cspinoff%", "%cdivest%", "%cmger%", "%crestruc%"
]
tag_clause = " OR ".join([f"subject_codes LIKE '{t}'" for t in action_tags])

# 2) Intent & action (with extra verbs)
intents = ["plan to","intend to","looking to","considering","mulling","weighing"]
actions = ["divest","sell","spin-off","dispose","carve-out"]
intent_clause = " OR ".join([f"body LIKE '%{i}%'" for i in intents])
action_clause = " OR ".join([f"body LIKE '%{a}%'" for a in actions])


where = (
"language_code='en' " 
"AND publication_datetime >= '2024-12-01 00:00:00' "
"AND region_codes LIKE '%eurz%' "
f"AND ({tag_clause}) "
f"AND ({intent_clause}) "
f"AND ({action_clause})"
)
query = {
  "query": {
    "where": where,
    "includesList":{
      "industry_codes": ["2ce88edb-3f5e-43c5-bf4b-48eb22624ff1"],
    },
  }
}

status, samples = run_explain(query)
# Out:
# Explain job created:
# Job ID: 50e56acc-7ce5-4052-bfb4-999a1e8f1375
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_RUNNING
# Waiting 10 seconds...
# Current state: JOB_STATE_DONE
#
# Getting samples for job ID: 50e56acc-7ce5-4052-bfb4-999a1e8f1375
#
# Number of documents matching the query: 2911
# {'data': {'attributes': {'counts': 5,
#                          'current_state': 'JOB_STATE_DONE',
#                          'sample': [{'an': 'ACWIRE0020241213ekcc000gq',
#                                      'company_codes': ',estind,ftamcg,ftamcg,ftamcg,linkd,onlnfr,pkxwks,rzlefe,rzlefe,seexc,sg,sg,sg,twnit,',
#                                      'company_codes_about': ',sg,ftamcg,',
#                                      'company_codes_occur': ',sg,rzlefe,ftamcg,',
#                                      'industry_codes': ',i25,i814,i81402,ibasicm,ibnk,ifinal,iibnk,',
#                                      'ingestion_datetime': '2024-12-13T01:13:35.000Z',
#                                      'modification_datetime': '2024-12-13T01:13:35.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2024-12-12T00:00:00.000Z',
#                                      'publisher_name': 'Accesswire',
#                                      'region_codes': ',asiaz,devgcoz,dvpcoz,eurz,india,sasiaz,',
#                                      'region_of_origin': 'CANA NAMZ ',
#                                      'restrictor_codes': ',ACWIRE,ACWIRE,CLNTALL,CTGAIIE,CTGAITR,EN,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId628884007,FSPMAPIPCCONAME,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC596034,FSPRBC893964,FSPRBCCO,FSPRBCCOM,FSPRBCCOSG,FSPRBCGROUP4102,FSPRBCGROUP4582,FSPRBCNS,FSPRBCNSNPRESS,FSPTHINGFINDER,FUTA,MPCCL,MPCDocHash6B670ADBC3C97630,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,NAMZ,TCUWIR,TPRW,TSCH,TTRK,TWIR,TYAS,TYLC,',
#                                      'source_code': 'ACWIRE',
#                                      'source_name': 'ACCESSWIRE',
#                                      'subject_codes': ',c18,c181,c24,cactio,ccat,ncat,nfact,nfcpin,npress,',
#                                      'title': 'Loop Industries Completes '
#                                               'Convertible Preferred Financing '
#                                               'With Reed Societe Generale '
#                                               'Group and Sells First '
#                                               'Technology License For An '
#                                               'Infinite Loop Manufacturing '
#                                               'Facility in Europe',
#                                      'word_count': 1732},
#                                     {'an': 'ACNENG0020241213ekcd00001',
#                                      'company_codes': ',estind,ftamcg,ftamcg,ftamcg,linkd,onlnfr,pkxwks,rzlefe,rzlefe,seexc,seexc,sg,sg,sg,twnit,',
#                                      'company_codes_about': ',sg,ftamcg,',
#                                      'company_codes_occur': ',sg,seexc,rzlefe,ftamcg,',
#                                      'industry_codes': ',i25,i43,i431,i483,i814,i81402,i9211,ibasicm,ibcs,ibnk,iclt,icnp,iewm,ifinal,iibnk,iindstrls,',
#                                      'ingestion_datetime': '2024-12-13T01:25:23.000Z',
#                                      'modification_datetime': '2024-12-13T01:25:23.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2024-12-13T09:10:00.000Z',
#                                      'publisher_name': 'Japan Corporate News '
#                                                        'Network K.K.',
#                                      'region_codes': ',asiaz,cana,caqc,devgcoz,dvpcoz,eurz,india,montre,namz,sasiaz,',
#                                      'region_of_origin': 'ASIA EASIA JAP ',
#                                      'restrictor_codes': ',ACNENG,ASIA,CLNTALL,EASIA,EN,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESCOORGOC,FSP2YESIN,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATIN,FSPCATNS,FSPCATRE,fspFileId628888710,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC596034,FSPRBC611156,FSPRBC721001,FSPRBC839658,FSPRBC853115,FSPRBC893964,FSPRBCCO,FSPRBCCOM,FSPRBCCOSG,FSPRBCGROUP4102,FSPRBCGROUP4582,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCGROUP6775,FSPRBCIN,FSPRBCINI9211,FSPRBCNS,FSPRBCNSC17,FSPRBCNSNPRESS,FSPRBCRE,FSPRBCRECAQC,FSPRBCREMONTRE,FSPTHINGFINDER,FUT,JAP,MPCCL,MPCDocHash532A05907C224095,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFACN,TGPW,TNOJP,TPRW,TQPR,TSCH,TTRK,TWIR,TYAS,TYLC,',
#                                      'source_code': 'ACNENG',
#                                      'source_name': 'ACN Newswire',
#                                      'subject_codes': ',c17,c18,c181,c33,c333,c334,cactio,ccat,ncat,nfact,nfcpin,npress,',
#                                      'title': 'Loop Industries Completes '
#                                               'Convertible Preferred Financing '
#                                               'With Reed Societe Generale '
#                                               'Group and Sells First '
#                                               'Technology License For An '
#                                               'Infinite Loop Manufacturing '
#                                               'Facility in Europe',
#                                      'word_count': 1647},
#                                     {'an': 'AKMENG0020250417el4h001mg',
#                                      'company_codes': ',aperls,aperls,aperls,autsd,autsd,autsd,bene,blgrou,blgrou,blgrou,gbenet,partsw,partsw,partsw,',
#                                      'company_codes_about': ',partsw,blgrou,autsd,aperls,',
#                                      'company_codes_occur': ',partsw,blgrou,autsd,aperls,',
#                                      'industry_codes': ',i502,i5020041,i81502,i8150203,i831,i83107,ialtinv,ibcs,iconst,icre,ifinal,iinv,irailtr,irdops,itsp,',
#                                      'ingestion_datetime': '2025-04-17T13:00:52.000Z',
#                                      'modification_datetime': '2025-04-17T13:00:52.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2025-04-17T00:00:00.000Z',
#                                      'publisher_name': 'Zao AK&M',
#                                      'region_codes': ',eecz,eurz,italy,medz,switz,weurz,',
#                                      'region_of_origin': 'ASIA EEURZ EUR RUSS '
#                                                          'USSRZ ',
#                                      'restrictor_codes': ',AKMENG,CLNTALL,CTGAIIE,CTGAITR,EEURZ,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId674762941,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621459,FSPRBC838785,FSPRBC842002,FSPRBC878686,FSPRBCCO,FSPRBCCOM,FSPRBCCOPARTSW,FSPRBCGROUP4102,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCGROUP80,FSPRBCNS,FSPRBCNSC181,FSPRBCRE,FSPRBCRESWITZ,FSPTHINGFINDER,FUT,MPCCL,MPCDocHash91DCEB5FDF93E93A,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,RUSS,SFAKM,TBIZ,TGORC,TGPW,TNWR,TSCH,TTRK,TWIR,TWWW,TYAS,TYLC,USSRZ,',
#                                      'source_code': 'AKMENG',
#                                      'source_name': 'AK&M',
#                                      'subject_codes': ',c18,c181,cactio,ccat,ncat,nfact,nfcpin,',
#                                      'title': 'Swiss Partners Group may sell '
#                                               'stake in Italian Telepass',
#                                      'word_count': 296},
#                                     {'an': 'AKMENG0020250320el3k002be',
#                                      'company_codes': ',cecplp,farfac,farfac,farfac,sptltd,sptltd,tpgpar,tpgpar,tpgpar,zrrsej,zrrsej,zrrsej,',
#                                      'company_codes_about': ',zrrsej,tpgpar,farfac,',
#                                      'company_codes_occur': ',zrrsej,tpgpar,sptltd,farfac,',
#                                      'industry_codes': ',i81501,i81502,i8150203,iabls,ialtinv,ibnk,ifinal,ifmsoft,iinv,impay,iplastic,itech,',
#                                      'ingestion_datetime': '2025-03-20T15:13:13.000Z',
#                                      'modification_datetime': '2025-03-20T15:13:13.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2025-03-20T00:00:00.000Z',
#                                      'publisher_name': 'Zao AK&M',
#                                      'region_codes': ',eecz,eurz,italy,medz,namz,usa,weurz,',
#                                      'region_of_origin': 'ASIA EEURZ EUR RUSS '
#                                                          'USSRZ ',
#                                      'restrictor_codes': ',AKMENG,CLNTALL,CTGAIIE,CTGAITR,EEURZ,EN,EUR,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATRE,fspFileId663443941,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC621478,FSPRBC648028,FSPRBC649124,FSPRBC686363,FSPRBC798521,FSPRBC840763,FSPRBC899111,FSPRBCCO,FSPRBCCOM,FSPRBCCOTPGPAR,FSPRBCCOZRRSEJ,FSPRBCGROUP4102,FSPRBCGROUP6577,FSPRBCGROUP6679,FSPRBCNS,FSPRBCNSC11,FSPRBCNSC181,FSPRBCNSC182,FSPRBCNSCACQU,FSPRBCRE,FSPRBCREUSA,FSPTHINGFINDER,FUT,MPCCL,MPCDocHash1C14AB68806E900D,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,RUSS,SFAKM,TBIZ,TGORC,TGPW,TNWR,TSCH,TTRK,TWIR,TWWW,TYAS,TYLC,USSRZ,',
#                                      'source_code': 'AKMENG',
#                                      'source_name': 'AK&M',
#                                      'subject_codes': ',c11,c18,c181,c182,cacqu,cactio,ccat,ncat,nfact,nfcpin,',
#                                      'title': 'The American TPG plans to buy '
#                                               'out part of the assets of the '
#                                               'Italian Nexi for $ 870 million',
#                                      'word_count': 315},
#                                     {'an': 'AWOPEN0020250415el4f0096l',
#                                      'company_codes': ',dtgrpg,dtgrpg,eqstry,eqstry,kkr,kkr,kkr,',
#                                      'company_codes_about': ',kkr,',
#                                      'company_codes_occur': ',kkr,eqstry,dtgrpg,',
#                                      'industry_codes': ',i81502,i8150206,ifinal,iinv,',
#                                      'ingestion_datetime': '2025-04-15T21:56:16.000Z',
#                                      'modification_datetime': '2025-04-15T21:56:16.000Z',
#                                      'newswires_codes': '',
#                                      'publication_datetime': '2025-04-15T21:56:08.000Z',
#                                      'publisher_name': 'awp Finanznachrichten '
#                                                        'AG',
#                                      'region_codes': ',eecz,eurz,gfr,weurz,',
#                                      'region_of_origin': 'EUR SWITZ WEURZ ',
#                                      'restrictor_codes': ',AWOPEN,CLNTALL,CTGAIAPI,CTGAIIR,EN,FSP2NOPEOC,FSP2YESCO,FSP2YESCOCOM,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,fspFileId673984643,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC594770,FSPRBC616551,FSPRBC704092,FSPRBC798521,FSPRBC890452,FSPRBC893964,FSPRBCGROUP11935,FSPRBCGROUP4582,FSPRBCGROUP6577,FSPRBCGROUP7683,FSPRBCNS,FSPRBCNSCACQU,FSPRBCNSCCAT,FSPRBCNSNPRESS,FSPRBCRE,FSPRBCREGFR,FSPTHINGFINDER,FUT,IFINAL,IINV,MPCCL,MPCDocHash6F87C955BC643B1C,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFAWP,TBIZ,TCUWIR,TNOJP,tnomci,TPRW,TSCH,TTRD,TTRK,TWIR,TYAS,TYLA,',
#                                      'source_code': 'AWOPEN',
#                                      'source_name': 'AWP Original Press '
#                                                     'Releases',
#                                      'subject_codes': ',c13,c18,c181,cacqu,cactio,ccat,ncat,nfact,nfcpin,npress,',
#                                      'title': 'EQS DATAGROUP enters into an '
#                                               'Investment Agreement with and '
#                                               'supports a public purchase '
#                                               'offer of KKR at a price of EUR '
#                                               '54.00 per share in cash',
#                                      'word_count': 719}]},
#           'id': '50e56acc-7ce5-4052-bfb4-999a1e8f1375',
#           'type': 'explain'},
#  'links': {'self': 'https://api.dowjones.com/extractions/samples/50e56acc-7ce5-4052-bfb4-999a1e8f1375'}}

# %% [markdown]
# ### Writing extraction query and getting the data! **DANGER - do not execute due to limits**
# Dangerous cells will be commented out

# %%
job_id = create_extraction(query)
# Out:
# 2025-04-29 12:27:54 [INFO] Creating extraction job...
# 2025-04-29 12:28:03 [INFO] Extraction job created: dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf

# %%
attrs = wait_for_extraction_completion(job_id)
# Out:
# 2025-04-29 12:28:18 [INFO] [Attempt 1/60] State: JOB_STATE_RUNNING
# 2025-04-29 12:28:18 [INFO] Sleeping for 10s before retry...
# 2025-04-29 12:28:28 [INFO] [Attempt 2/60] State: JOB_STATE_RUNNING
# 2025-04-29 12:28:28 [INFO] Sleeping for 15.0s before retry...
# 2025-04-29 12:28:44 [INFO] [Attempt 3/60] State: JOB_STATE_RUNNING
# 2025-04-29 12:28:44 [INFO] Sleeping for 22.5s before retry...
# 2025-04-29 12:29:07 [INFO] [Attempt 4/60] State: JOB_STATE_RUNNING
# 2025-04-29 12:29:07 [INFO] Sleeping for 33.75s before retry...
# 2025-04-29 12:29:41 [INFO] [Attempt 5/60] State: JOB_STATE_RUNNING
# 2025-04-29 12:29:41 [INFO] Sleeping for 50.625s before retry...
# 2025-04-29 12:30:33 [INFO] [Attempt 6/60] State: JOB_STATE_DONE

# %%
files = attrs.get("files", [])
download_files(files, job_id)
logging.info(f"Extraction {job_id} complete.")
# Out:
# 2025-04-29 12:34:16 [INFO] Downloading 1 files into '/home/alk/Projects/carveouts_poc/extractions/dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf'
# 2025-04-29 12:34:16 [INFO] -> Downloading part-000000000000.avro
# 2025-04-29 12:34:25 [INFO]    Saved to /home/alk/Projects/carveouts_poc/extractions/dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf/part-000000000000.avro
# 2025-04-29 12:34:25 [INFO] Extraction dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf complete.

# %% [markdown]
# ## Reading .avro file and converting it to csv

# %%
from fastavro import reader
import pandas as pd

def read_avro_file(path):
    """
    Yield each record (as a dict) from an Avro file.
    """
    with open(path, 'rb') as fo:
        avro_reader = reader(fo)
        for record in avro_reader:
            yield record

def records2df(records):
    """
    Convert a list of records to a pandas DataFrame.
    """
    df = pd.DataFrame(records)
    return df
# Usage example
file_path = '../../extractions/dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf/part-000000000000.avro'
records = list(read_avro_file(file_path))
print(f"Read {len(records)} records.")

records_df = pd.DataFrame.from_records(records)
records_df.to_csv('../../extractions/dj-synhub-extraction-lkbi9fy6zepu8rcjuxqhjwkbld52wgt0-l0fy7lkzhf/result.csv', index=False)
# Out:
# Read 2911 records.

# %% [markdown]
# ### Viewing samples

# %%
explain_job_id = "fc06f298-dba6-4002-b4e8-06819322f34b"
samples_url = f"https://api.dowjones.com/extractions/samples/{explain_job_id}?num_samples=5"
samples_response = requests.get(samples_url, headers=headers)
samples = samples_response.json()

# %%
samples
# Out:
# {'data': {'id': 'fc06f298-dba6-4002-b4e8-06819322f34b',
#   'type': 'explain',
#   'attributes': {'counts': 5,
#    'current_state': 'JOB_STATE_DONE',
#    'sample': [{'an': 'OHFSEC0020240524ek5m00001',
#      'company_codes': ',omniho,omniho,',
#      'company_codes_about': '',
#      'company_codes_occur': ',omniho,',
#      'industry_codes': ',i41,i412,i4122,i4221,i4222,icnp,ifood,',
#      'ingestion_datetime': '2024-05-24T00:30:29.000Z',
#      'modification_datetime': '2024-05-24T00:30:29.000Z',
#      'publication_datetime': '2024-05-22T00:00:00.000Z',
#      'publisher_name': 'Brownstein & Egusa',
#      'region_codes': ',eurz,uk,weurz,',
#      'region_of_origin': 'EEURZ EUR HUNG ',
#      'source_code': 'OHFSEC',
#      'source_name': '150sec',
#      'subject_codes': ',c22,ccat,cemis,centrp,cenvire,cesg,cexpro,cpartn,csmlbs,ncat,nfact,nfcpex,nfcpin,',
#      'title': 'UK’s Pet-Tech Venture Launches Cultivated Chicken And Other Meat Products',
#      'word_count': 490,
#      'newswires_codes': '',
#      'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOPEOC,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATIN,FSPCATNS,FSPCATRE,fspFileId548436724,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC624992,FSPRBC855249,FSPRBC880024,FSPRBC884048,FSPRBCGROUP188,FSPRBCGROUP373,FSPRBCGROUP6577,FSPRBCGROUP8184,FSPRBCNS,FSPRBCNSCENTRP,FSPRBCRE,FSPRBCREUK,FUTA,MPCCL,MPCDocHashB8AE943E02C91466,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,tnomci,TSCH,TTRK,TYAS,TYLD,'},
#     {'an': 'OHFSEC0020240702ek7200001',
#      'company_codes': ',omniho,omniho,',
#      'company_codes_about': '',
#      'company_codes_occur': ',omniho,',
#      'industry_codes': ',i98203,ibcs,iscsv,',
#      'ingestion_datetime': '2024-07-02T18:31:51.000Z',
#      'modification_datetime': '2024-07-02T18:31:51.000Z',
#      'publication_datetime': '2024-07-02T00:00:00.000Z',
#      'publisher_name': 'Brownstein & Egusa',
#      'region_codes': ',eurz,',
#      'region_of_origin': 'EEURZ EUR HUNG ',
#      'source_code': 'OHFSEC',
#      'source_name': '150sec',
#      'subject_codes': ',ccat,centrp,csmlbs,ncat,nfact,nfcpex,',
#      'title': '5 European Pet Tech Innovators To Keep An Eye On In 2024',
#      'word_count': 1059,
#      'newswires_codes': '',
#      'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOPEOC,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESIN,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATIN,FSPCATRE,fspFileId565298257,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC880024,FSPRBC881759,FSPRBCGROUP188,FSPRBCGROUP325,FSPRBCNS,FSPRBCNSCENTRP,FUTA,MPCCL,MPCDocHash5F93C370BEFF7232,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,TSCH,TTRK,TYAS,TYLD,'},
#     {'an': 'OHFSEC0020240613ek6c00001',
#      'company_codes': ',acptef,acptef,amzcom,amzcom,andac,andac,apcbac,apcbac,auifch,auifch,binter,eucmm,euruno,euruno,farada,farada,gognew,gognew,hpjqvv,hpjqvv,iesesp,iesesp,intth,intth,prwth,prwth,qexwvp,qexwvp,rcktig,rcktig,unchld,unpom,unpom,unwest,unwest,vubfub,vubfub,',
#      'company_codes_about': '',
#      'company_codes_occur': ',vubfub,unwest,unpom,rcktig,qexwvp,prwth,intth,iesesp,hpjqvv,gognew,farada,euruno,auifch,apcbac,andac,amzcom,acptef,',
#      'industry_codes': '',
#      'ingestion_datetime': '2024-06-13T18:31:36.000Z',
#      'modification_datetime': '2024-06-13T18:31:36.000Z',
#      'publication_datetime': '2024-06-12T00:00:00.000Z',
#      'publisher_name': 'Brownstein & Egusa',
#      'region_codes': ',castil,eecz,eurz,lamz,medz,spain,weurz,',
#      'region_of_origin': 'EEURZ EUR HUNG ',
#      'source_code': 'OHFSEC',
#      'source_name': '150sec',
#      'subject_codes': ',ccat,centrp,cenvire,cesg,csmlbs,ncat,nfact,nfcpex,',
#      'title': 'Top 15 Spanish Investors to Watch in 2024',
#      'word_count': 2615,
#      'newswires_codes': '',
#      'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOIN,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESCOORGOC,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId556295270,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC647516,FSPRBC881759,FSPRBC890316,FSPRBC890452,FSPRBCGROUP11935,FSPRBCGROUP325,FSPRBCGROUP6679,FSPRBCNS,FSPRBCNSCENTRP,FSPRBCRE,FSPRBCRECASTIL,FUTA,MPCCL,MPCDocHashA0B1EEB02780D7EF,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,tnomci,TSCH,TTRK,TYAS,TYLD,'},
#     {'an': 'OHFSEC0020241029ekas00001',
#      'company_codes': ',airfre,decon,easjet,euruno,maym,nasam,rynaer,',
#      'company_codes_about': '',
#      'company_codes_occur': '',
#      'industry_codes': ',i3302022,itech,',
#      'ingestion_datetime': '2024-10-29T00:30:32.000Z',
#      'modification_datetime': '2024-10-29T00:30:32.000Z',
#      'publication_datetime': '2024-10-28T00:00:00.000Z',
#      'publisher_name': 'Brownstein & Egusa',
#      'region_codes': ',czrep,devgcoz,eecz,eeurz,eurz,',
#      'region_of_origin': 'EEURZ EUR HUNG ',
#      'source_code': 'OHFSEC',
#      'source_name': '150sec',
#      'subject_codes': ',ccat,centrp,csmlbs,ncat,nfact,nfcpex,',
#      'title': 'What’s cooking in Brno, Czechia’s tech scene: 15 innovators to watch\xa0',
#      'word_count': 1552,
#      'newswires_codes': '',
#      'restrictor_codes': ',CLNTALL,CTGAIIE,EEURZ,EN,EUR,FSP2NOCO,FSP2NOCOOC,FSP2YESIN,FSP2YESNS,FSP2YESPEOC,FSP2YESRE,FSPCATEGORIZER,FSPCATIN,FSPCATRE,fspFileId612143649,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC853374,FSPRBC880024,FSPRBC890452,FSPRBCGROUP11935,FSPRBCGROUP188,FSPRBCGROUP6679,FSPRBCNS,FSPRBCNSCENTRP,FSPRBCRE,FSPRBCRECZREP,FUTA,MPCCL,MPCDocHashA83C5FF466928891,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,OHFSEC,OHFSEC,TBIZ,TINT,TMAG,tnomci,TSCH,TTRK,TYAS,TYLD,'},
#     {'an': 'SOLRADIN20240827ek8r00209',
#      'company_codes': ',bnzl,bnzl,cgw,cgw,enel,enel,gldmns,gldmns,ubs,ubs,wesah,',
#      'company_codes_about': '',
#      'company_codes_occur': ',ubs,gldmns,enel,cgw,bnzl,',
#      'industry_codes': '',
#      'ingestion_datetime': '2024-08-27T09:57:46.000Z',
#      'modification_datetime': '2024-08-27T09:57:46.000Z',
#      'publication_datetime': '2024-08-27T09:57:00.000Z',
#      'publisher_name': 'Il Sole 24 Ore SpA',
#      'region_codes': ',eecz,eurz,italy,medz,weurz,',
#      'region_of_origin': 'EUR ITALY MEDZ WEURZ ',
#      'source_code': 'SOLRADIN',
#      'source_name': '24 Ore Radiocor-Newswire International Edition',
#      'subject_codes': ',c17,c171,c18,c181,cactio,ccat,cshbuy,m11,mcat,ncat,nfact,nfce,nfcpin,niwe,nrmf,',
#      'title': 'European shares higher after DJIA sets new record high -2-',
#      'word_count': 384,
#      'newswires_codes': '',
#      'restrictor_codes': ',CLNTALL,CTGAIIE,EN,EUR,FSP2NOCO,FSP2NOIN,FSP2NOPEOC,FSP2YESCOCOMOC,FSP2YESCOOC,FSP2YESNS,FSP2YESRE,FSPCATEGORIZER,FSPCATNS,FSPCATRE,fspFileId587421600,FSPNORMAWS0500,FSPNORMAWSMQ,FSPRBC,FSPRBC182991,FSPRBC257741,FSPRBC718922,FSPRBC780788,FSPRBC890452,FSPRBCGROUP11935,FSPRBCGROUP4582,FSPRBCGROUP4583,FSPRBCGROUP6577,FSPRBCNS,FSPRBCNSCSHBUY,FSPRBCNSM11,FSPRBCNSNRMF,FUT,IFINAL,IINV,ITALY,MEDZ,MPCCL,MPCDocHash8F676791B5339AA9,MPCEnvPROD,MPCESIN,MPCESNS,MPCESRE,MPCJP,MPCKP,MPCKW,MPCRBC,MPCV1M23M0B1,SFSOLE,SOLRADIN,TCUWIR,TFCDLIC,tnomci,TNWR,TSCH,TTRD,TTRK,TWIR,TWWW,TYAS,TYLA,WEURZ,'}]}},
#  'links': {'self': 'https://api.dowjones.com/extractions/samples/fc06f298-dba6-4002-b4e8-06819322f34b'}}
